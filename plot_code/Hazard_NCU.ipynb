# %%
import os
import pygmt
import pandas as pd
# Homework assignment for PSHA by Chung Han Chan
# Read synthetic catalog to calculate the PSHA
fig = pygmt.Figure()
# config
#pygmt.config(MAP_FRAME_TYPE="plain")
#pygmt.config(FORMAT_GEO_MAP="ddd.xx")
pygmt.makecpt(cmap="seis",series=[0,0.1])
#
cata = pd.read_csv("cat_out_100.dat",
                   delim_whitespace=True,
                   header=1,
                   names=["year","lat","long","dep","mag"])
#print(cata)
# Area
fig.coast(
    region=[120.2, 122.2,24, 25.8],
    projection="M8i",
    land="grey",
    water="lightblue",
    shorelines=True,
    resolution="f",
    frame='a'
)
# Source area

#
#fig.plot(
#    x=[0,0],
#    y=[-1,1],
#    pen="1,red,-",
#)
# Target
fig.plot(
    x=121.194,
    y=24.967,
    style="t0.3i",
    pen='thick',
    color = "green"
)
fig.text(text="PGA=0.042(g)",x=121, y=25, font="14p,red")
#fig.text(text="PGA=0.24(g)",x=0.1, y=0.1, font="14p,red")
# source plot
# Plot the area source
S = pd.read_csv("area_source/S01.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black") # Zone 1
#
S = pd.read_csv("area_source/S04.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black") 
#
S = pd.read_csv("area_source/S05A.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S05B.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S06.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S09.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S10.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S14A.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S14B.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S15.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
S = pd.read_csv("area_source/S17A.txt",delim_whitespace=True,header=1,names=["long","lat"])
fig.plot(x=S.long,y=S.lat,pen="3,black")
#
# Catalog plot
fig.plot(x=cata.long,
         y=cata.lat,
         sizes=0.005*(2**cata.mag),
         style="cc",
         color="blue",
         pen="black")
# Fault line

# 
F = pd.read_csv("faults/1.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/2.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/3.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/4.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/5.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/6.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/7.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/8.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/9.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/10.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/11.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/12.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/13.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/14.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/15.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/16.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/17.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/18.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/32.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/33.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/37.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")

F = pd.read_csv("faults/38.txt",delim_whitespace=True,header=1,names=["x1","y1"])
fig.plot(x=F.x1,y=F.y1,pen="3,red")
#
#fig.colorbar(frame='af+l"PGA(g)"')
fig.savefig("Hazard_NCU.png")
fig.show()

# %%
pga=0.22
print(pga)
# Out:
# 0.22
